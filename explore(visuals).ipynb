# %% [markdown]
# <a id="TableOfContents"></a>
# # TABLE OF CONTENTS:
# <li><a href='#imports'>Imports</a></li>
# <li><a href="#telco">Get Telco Dataset</a></li>
# <li><a href="#quantitative">Explore Quantitative</a></li>
# <li><a href="#categorical">Explore Categorical</a></li>
# <li><a href="#val_vs_cat">Explore Values vs. Categorical</a></li>
# <li><a href="#additionalexploration">Additional Exploration</a></li>

# %% [markdown]
# ##### Orientation:
# The purpose of this file is to explore the 'telco' dataset and figure out possible influencers to customer churn rate.

# %% [markdown]
# <a id='imports'></a>
# # IMPORTS:
# <li><a href='#TableOfContents'>Table of Contents</a></li>

# %%
# Basic
import numpy as np
import pandas as pd

# Visualizations
import seaborn as sns
import matplotlib.pyplot as plt

# Get cleaned 'telco'
import prepare

# Functions to assist with exploration
import explore

# %% [markdown]
# <a id='telco'></a>
# # Get Telco Dataset:
# <li><a href='#TableOfContents'>Table of Contents</a></li>

# %%
# Acquire cleaned 'telco' dataset
telco = prepare.prep_telco()
telco.sample()
# Out:
#      gender  senior_citizen partner dependents  tenure phone_service  \
# 5467   Male               1      No         No      52           Yes
#
#      multiple_lines online_security online_backup device_protection  ...  \
# 5467            Yes              No            No                No  ...
#
#      contract_type_Two year internet_service_type_DSL  \
# 5467                      0                         0
#
#      internet_service_type_Fiber optic internet_service_type_None  \
# 5467                                 1                          0
#
#       payment_type_Bank transfer (automatic)  \
# 5467                                       1
#
#       payment_type_Credit card (automatic) payment_type_Electronic check  \
# 5467                                     0                             0
#
#      payment_type_Mailed check total_services total_extra_services
# 5467                         0              3                    0
#
# [1 rows x 67 columns]

# %% [markdown]
# <a id='quantitative'></a>
# # Explore Quantitative:
# <li><a href='#TableOfContents'>Table of Contents</a></li>

# %%
# Use function to explore all value cols
explore.quantitative(telco)
# Out:
# /usr/local/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# |       |   senior_citizen |
# |:------|-----------------:|
# | count |      7043        |
# | mean  |         0.162147 |
# | std   |         0.368612 |
# | min   |         0        |
# | 25%   |         0        |
# | 50%   |         0        |
# | 75%   |         0        |
# | max   |         1        |
#
# ...
# /usr/local/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %% [markdown]
# ### Takeaways:
# - Majorities
#     - Non-senior citizen
#     - total_charges low
# - Right-Skew
#     - total_services
#     - total_extra_services
# - Misc
#     - tenure shaped like 'U'
#     - monthly_charges two-humps

# %% [markdown]
# <a id='categorical'></a>
# # Explore Categorical:
# <li><a href='#TableOfContents'>Table of Contents</a></li>

# %%
# Use function to explore all value cols
explore.categorical(telco)
# Out:
#         Count  Percentage
# Male     3555    0.504756
# Female   3488    0.495244
#
# ...
#      Count  Percentage
# No    3641    0.516967
# Yes   3402    0.483033
#
# ...
#      Count  Percentage
# No    4933    0.700412
# Yes   2110    0.299588
#
# ...
#      Count  Percentage
# Yes   6361    0.903166
# No     682    0.096834
#
# ...
#                   Count  Percentage
# No                 3390    0.481329
# Yes                2971    0.421837
# No phone service    682    0.096834
#
# ...
#                      Count  Percentage
# No                    3498    0.496663
# Yes                   2019    0.286668
# No internet service   1526    0.216669
#
# ...
#                      Count  Percentage
# No                    3088    0.438450
# Yes                   2429    0.344881
# No internet service   1526    0.216669
#
# ...
#                      Count  Percentage
# No                    3095    0.439443
# Yes                   2422    0.343888
# No internet service   1526    0.216669
#
# ...

# %% [markdown]
# ### Takeaways:
# - Majorities
#     - No Dependents
#     - Has phone service
#     - Month-to-Month Contract

# %% [markdown]
# <a id='val_vs_cat'></a>
# # Explore Values vs. Categorical:
# <li><a href='#TableOfContents'>Table of Contents</a></li>

# %%
# Use function to explore all val vs cat cols
explore.cat_vs_val(telco)
# Out:
# |       |      Female |        Male |
# |:------|------------:|------------:|
# | count | 3488        | 3555        |
# | mean  |    0.162844 |    0.161463 |
# | std   |    0.369276 |    0.368009 |
# | min   |    0        |    0        |
# | 25%   |    0        |    0        |
# | 50%   |    0        |    0        |
# | 75%   |    0        |    0        |
# | max   |    1        |    1        |
#
# ...
# |       |    Female |      Male |
# |:------|----------:|----------:|
# | count | 3488      | 3555      |
# | mean  |   32.2446 |   32.4954 |
# | std   |   24.4632 |   24.6564 |
# | min   |    0      |    0      |
# | 25%   |    9      |    9      |
# | 50%   |   29      |   29      |
# | 75%   |   55      |   56      |
# | max   |   72      |   72      |
#
# ...
# |       |    Female |      Male |
# |:------|----------:|----------:|
# | count | 3488      | 3555      |
# | mean  |   65.2042 |   64.3275 |
# | std   |   30.0613 |   30.1161 |
# | min   |   18.4    |   18.25   |
# ...

# %%
# Further exploration into tenure
catcols = telco.select_dtypes(include='int')
for col in catcols:
    sns.boxplot(data=telco, x=telco[col], y='tenure')
    plt.show()

# %% [markdown]
# ### Takeaways:
# - Longer Tenure
#     - 'partner' = 'Yes'
#     - 'dependents' = 'Yes'
#     - 'multiple_lines' = 'Yes'
#     - 'online_security' = 'Yes'
#     - 'online_backup' = 'Yes'
#     - 'device_protection' = 'Yes'
#     - 'tech_support' = 'Yes'
#     - 'streaming_tv' = 'Yes'
#     - 'streaming_movies' = 'Yes'
#     - 'payment_type' = 'Bank transfer (automatic)' or 'Credit Card (automatic)'
#     - 'contract_type' = 'One year' or 'Two year'
#     - As 'total_services' increase
#     - As 'total_extra_services' increase
# - Retention cols
#     - 'monthly_charges' approx. 60
# - Losing cols
#     - 'senior_citizen'
# - Churn happens around 15-20 months

# %% [markdown]
# <a id='additionalexploration'></a>
# # Additional Exploration:
# <li><a href='#TableOfContents'>Table of Contents</a></li>

# %%
# Longer tenure cols vs. churn
longertenure = [
    'partner',
    'dependents',
    'multiple_lines',
    'online_security',
    'online_backup',
    'device_protection',
    'tech_support',
    'streaming_tv',
    'streaming_movies',
    'payment_type',
    'contract_type',
    'total_services',
    'total_extra_services'
]
for x in longertenure:
    sns.histplot(data=telco, x=telco[x], hue='churn', multiple='dodge')
    plt.show()

# %% [markdown]
# ### Takeaways:
# - Less Likely to Churn
#     - 'partner' = 'Yes'
#     - 'dependents' = 'Yes'
#     - 'online_security' = 'Yes', 'No internet service'
#     - 'online_backup = 'No internet service'
#     - 'device_protection' = 'Yes', 'No internet service'
#     - 'tech_support' = 'Yes', 'No internet service'
#     - 'streaming_tv' = 'No internet service'
#     - 'streaming_movies' = 'No internet service'
#     - 'contract_type' = 'One year', 'Two year'
#     - 'total_services' = '1', '6', '7', '8', '9'
#     - 'total_extra_services' = '0', '3', '4', '5', '6'
# - AVOID
#     - 'payment_type' = 'Electronic check'
#     - 'contract_type' = 'Month-to-month'
#     - 'total_services'= '3', '4'
#     - 'total_extra_services' = '1', '2'

# %% [markdown]
# ### Additional Comment:
# - Target audience:
#     - Couples
#     - Families/Dependents
# - Services Emphasis:
#     - Cell Services:
#         - Not much difference with/without/multiple
#     - Internet Services:
#         - Either no internet or at least bundle 3 subs
# - Payments:
#     - DO NOT ALLOW ELECTRONIC CHECK
# - Contracts:
#     - DO NOT ALLOW MONTH CONTRACT
